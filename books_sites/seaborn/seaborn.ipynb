# %% [markdown]
# https://github.com/mwaskom/seaborn/issues/1502

# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

df = pd.read_csv("http://vincentarelbundock.github.io/Rdatasets/csv/MASS/nlschools.csv", index_col=0)
df.head()
# Out:
# /Users/shotaroishihara/.pyenv/versions/3.6.3/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
#    lang    IQ  class  GS  SES  COMB
# 1    46  15.0    180  29   23     0
# 2    45  14.5    180  29   10     0
# 3    33   9.5    180  29   15     0
# 4    46  11.0    180  29   23     0
# 5    20   8.0    180  29   10     0

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="COMB")
