# %%
import pandas as pd

url = 'http://soccer-fam.jp/jleague-j2j3-history'
dfs = pd.read_html(url)

# %%
dfs[1]
# Out:
#        0          1          2      3        4
# 0     年度       J2降格       J1昇格   J3降格     J2昇格
# 1   1998         札幌          –      –        –
# 2   1999      浦和 平塚    川崎F F東京      –        –
# 3   2000     京都 川崎F      札幌 浦和      –        –
# 4   2001     福岡 C大阪      京都 仙台      –        –
# 5   2002      広島 札幌     大分 C大阪      –        –
# 6   2003      仙台 京都      新潟 広島      –        –
# 7   2004       (※1)     川崎F 大宮      –        –
# 8   2005   柏 東京V 神戸   京都 福岡 甲府      –        –
# 9   2006  福岡 C大阪 京都   横FC 柏 神戸      –        –
# 10  2007  広島 甲府 横FC  札幌 東京V 京都      –        –
# 11  2008     東京V 札幌      広島 山形      –        –
# 12  2009    柏 大分 千葉  仙台 C大阪 湘南      –        –
# 13  2010  F東京 京都 湘南    柏 甲府 福岡      –        –
# 14  2011   甲府 福岡 山形  F東京 鳥栖 札幌      –        –
# 15  2012  神戸 G大阪 札幌   甲府 湘南 大分      –        –
# 16  2013   湘南 磐田 大分  G大阪 神戸 徳島     鳥取  讃岐 (※2)
# 17  2014  大宮 C大阪 徳島   湘南 松本 山形     富山       金沢
# 18  2015   松本 清水 山形   大宮 磐田 福岡  大分 栃木    山口 町田
# ...

# %%
df = dfs[1]
df.columns = df.loc[0]
df = df[['年度', 'J2降格', 'J1昇格']].iloc[1:-1, :]

# %%
df = pd.read_clipboard()

# %%
df
# Out:
#     J2降格年度    チーム名  J1昇格年度  J2滞在年数
# 0     1998      札幌  2000.0       2
# 1     1999      浦和  2000.0       1
# 2     1999  平塚(湘南)  2009.0      10
# 3     2000      京都  2001.0       1
# 4     2000      川崎  2004.0       4
# 5     2001      福岡  2005.0       4
# 6     2001     C大阪  2002.0       1
# 7     2002      広島  2003.0       1
# 8     2002      札幌  2007.0       5
# 9     2003      仙台  2009.0       6
# 10    2003      京都  2005.0       2
# 11    2005       柏  2006.0       1
# 12    2005     東京V  2007.0       2
# 13    2005      神戸  2006.0       1
# 14    2006      福岡  2010.0       4
# 15    2006     C大阪  2009.0       3
# 16    2006      京都  2007.0       1
# 17    2007      広島  2008.0       1
# 18    2007      甲府  2010.0       3
# 19    2007     横FC     NaN   -2007
# 20    2008     東京V     NaN   -2008
# 21    2008      札幌  2011.0       3
# 22    2009       柏  2010.0       1
# 23    2009      大分  2012.0       3
# 24    2009      千葉     NaN   -2009
# 25    2010     F東京  2011.0       1
# ...
